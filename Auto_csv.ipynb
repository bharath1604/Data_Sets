# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas_profiling

# %%
Au=pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/Autos.csv')

# %%
Au
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
Au.replace('?',np.nan,inplace=True)

# %%
Au
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3               NaN  alfa-romero       gas
# 1             1          3               NaN  alfa-romero       gas
# 2             2          1               NaN  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
Au.head()
# Out:
#    Unnamed: 0  symboling normalized-losses         make fuel-type aspiration  \
# 0           0          3                 ?  alfa-romero       gas        std
# 1           1          3                 ?  alfa-romero       gas        std
# 2           2          1                 ?  alfa-romero       gas        std
# 3           3          2               164         audi       gas        std
# 4           4          2               164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 0          two  convertible          rwd           front  ...          130
# 1          two  convertible          rwd           front  ...          130
# 2          two    hatchback          rwd           front  ...          152
# 3         four        sedan          fwd           front  ...          109
# 4         four        sedan          4wd           front  ...          136
#
# ...

# %%
Au.tail()
# Out:
#      Unnamed: 0  symboling normalized-losses   make fuel-type aspiration  \
# 200         200         -1                95  volvo       gas        std
# 201         201         -1                95  volvo       gas      turbo
# 202         202         -1                95  volvo       gas        std
# 203         203         -1                95  volvo    diesel      turbo
# 204         204         -1                95  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  ...  engine-size  \
# 200         four      sedan          rwd           front  ...          141
# 201         four      sedan          rwd           front  ...          141
# 202         four      sedan          rwd           front  ...          173
# 203         four      sedan          rwd           front  ...          145
# 204         four      sedan          rwd           front  ...          141
#
#      fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  \
# ...

# %%
Au.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                 ?  alfa-romero       gas
# 1             1          3                 ?  alfa-romero       gas
# 2             2          1                 ?  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
Au['normalized-losses'].replace('?','hi',inplace=True)

# %%
Au
# Out:
#      Unnamed: 0  symboling normalized-losses         make fuel-type  \
# 0             0          3                hi  alfa-romero       gas
# 1             1          3                hi  alfa-romero       gas
# 2             2          1                hi  alfa-romero       gas
# 3             3          2               164         audi       gas
# 4             4          2               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200         -1                95        volvo       gas
# 201         201         -1                95        volvo       gas
# 202         202         -1                95        volvo       gas
# 203         203         -1                95        volvo    diesel
# 204         204         -1                95        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# ...

# %%
Au.shape
# Out:
# (205, 27)

# %%
Au.size
# Out:
# 5535

# %%
Au.ndim
# Out:
# 2

# %%
Au.isnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make  fuel-type  aspiration  \
# 0         False      False              False  False      False       False
# 1         False      False              False  False      False       False
# 2         False      False              False  False      False       False
# 3         False      False              False  False      False       False
# 4         False      False              False  False      False       False
# ..          ...        ...                ...    ...        ...         ...
# 200       False      False              False  False      False       False
# 201       False      False              False  False      False       False
# 202       False      False              False  False      False       False
# 203       False      False              False  False      False       False
# 204       False      False              False  False      False       False
#
# ...

# %%
Au.notna()
# Out:
#      Unnamed: 0  symboling  normalized-losses  make  fuel-type  aspiration  \
# 0          True       True               True  True       True        True
# 1          True       True               True  True       True        True
# 2          True       True               True  True       True        True
# 3          True       True               True  True       True        True
# 4          True       True               True  True       True        True
# ..          ...        ...                ...   ...        ...         ...
# 200        True       True               True  True       True        True
# 201        True       True               True  True       True        True
# 202        True       True               True  True       True        True
# 203        True       True               True  True       True        True
# 204        True       True               True  True       True        True
#
#      num-of-doors  body-style  drive-wheels  engine-location  ...  \
# ...

# %%
Au.notnull()
# Out:
#      Unnamed: 0  symboling  normalized-losses  make  fuel-type  aspiration  \
# 0          True       True               True  True       True        True
# 1          True       True               True  True       True        True
# 2          True       True               True  True       True        True
# 3          True       True               True  True       True        True
# 4          True       True               True  True       True        True
# ..          ...        ...                ...   ...        ...         ...
# 200        True       True               True  True       True        True
# 201        True       True               True  True       True        True
# 202        True       True               True  True       True        True
# 203        True       True               True  True       True        True
# 204        True       True               True  True       True        True
#
#      num-of-doors  body-style  drive-wheels  engine-location  ...  \
# ...

# %%
Au.mean()
# Out:
# Unnamed: 0            102.000000
# symboling               0.834146
# wheel-base             98.756585
# length                174.049268
# width                  65.907805
# height                 53.724878
# curb-weight          2555.565854
# engine-size           126.907317
# compression-ratio      10.142537
# city-mpg               25.219512
# highway-mpg            30.751220
# dtype: float64

# %%
Au.median()
# Out:
# Unnamed: 0            102.0
# symboling               1.0
# wheel-base             97.0
# length                173.2
# width                  65.5
# height                 54.1
# curb-weight          2414.0
# engine-size           120.0
# compression-ratio       9.0
# city-mpg               24.0
# highway-mpg            30.0
# dtype: float64

# %%
pandas_profiling.ProfileReport(Au)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
Au.corr()
# Out:
#                    Unnamed_0  symboling  wheel-base    length     width  \
# Unnamed_0           1.000000  -0.151621    0.129729  0.170636  0.052387
# symboling          -0.151621   1.000000   -0.531954 -0.357612 -0.232919
# wheel-base          0.129729  -0.531954    1.000000  0.874587  0.795144
# length              0.170636  -0.357612    0.874587  1.000000  0.841118
# width               0.052387  -0.232919    0.795144  0.841118  1.000000
# height              0.255960  -0.541038    0.589435  0.491029  0.279210
# curb-weight         0.071962  -0.227691    0.776386  0.877728  0.867032
# engine-size        -0.033930  -0.105790    0.569329  0.683360  0.735433
# compression-ratio   0.150276  -0.178515    0.249786  0.158414  0.181129
# city-mpg            0.015940  -0.035823   -0.470414 -0.670909 -0.642704
# highway-mpg         0.011255   0.034606   -0.544082 -0.704662 -0.677218
#
#                      height  curb-weight  engine-size  compression-ratio  \
# ...

# %%
sns.heatmap(Au.corr())
